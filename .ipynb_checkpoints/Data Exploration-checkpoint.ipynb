# %%
# Read in the dataset
import csv
import pandas as pd

data = pd.read_csv("data/covars_and_biological_ds5500.csv")

data.head()
# Out:
#    STUDYID    ED  CURRJOB  FVINC  SMKEVER  SMK  SMK100  SMKYRS  LASTCIG  \
# 0     1001  14.0      2.0  999.0      0.0  NaN     NaN     NaN      NaN
# 1     1006  12.0      2.0  888.0      0.0  NaN     NaN     NaN      NaN
# 2     1009  14.0      2.0    1.0      1.0  0.0     0.0     0.0      4.0
# 3     1012   8.0      2.0    1.0      1.0  0.0     0.0     0.0      4.0
# 4     1013   9.0      2.0    3.0      0.0  NaN     NaN     NaN      NaN
#
#    SMKDAILY_MY  ...  _8_ISO_V4  _8_ISOM_V1  _8_ISOM_V2  _8_ISOM_V3  \
# 0          NaN  ...        NaN         NaN         NaN         NaN
# 1          NaN  ...        NaN         NaN         NaN         NaN
# 2          0.0  ...        NaN         NaN         NaN         NaN
# 3          0.0  ...        NaN         NaN         NaN         NaN
# 4          NaN  ...        NaN         NaN         NaN         NaN
#
#    _8_ISOM_V4  PRETERM_BEST  FINALGA_BEST  SPECIFICGRAVITY_V1  \
# 0         NaN             0     37.428571               1.019
# ...
